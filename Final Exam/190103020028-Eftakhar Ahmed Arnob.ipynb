# %% [markdown]
# ## Ans of question : 1

# %%
import numpy as np

z = float(input())

ztanh = float((np.exp(z) - np.exp(-z)) / (np.exp(z) + np.exp(-z)))

print(ztanh)
# Out:
# 0.5
# 0.4621171572600098

# %% [markdown]
# ## Ans of question : 2

# %%
import pandas as pd
import numpy as np
import random


A = []
for i in range(0,100) :
    n = random.uniform(0,1)
    A.append(n)
    
B = []
for i in range(0,100) :
    n = random.uniform(0,1)
    B.append(n)
    
C = []
for i in range(0,100) :
    n = random.uniform(0,1)
    C.append(n)
    
D = []
for i in range(0,100) :
    n = random.uniform(0,1)
    D.append(n)
    
T = []
for i in range(0,100) :
    for i in range(0,100):
        if(A[i] + B[i] + C[i] + D[i] >= 0.5) :
            n = 1
        else:
            n = 0
    T.append(n)    


def generatedData() :
    data = pd.DataFrame({"A":A, "B":B, "C":C, "D":D, "T":T})
    print(data)

if __name__ == "__main__" :
    generatedData()
# Out:
#            A         B         C         D  T
# 0   0.076638  0.913575  0.534839  0.133994  1
# 1   0.839501  0.891919  0.411095  0.054158  1
# 2   0.151227  0.598870  0.742290  0.769709  1
# 3   0.467045  0.323277  0.535243  0.904033  1
# 4   0.579710  0.935719  0.236740  0.980462  1
# ..       ...       ...       ...       ... ..
# 95  0.683978  0.874814  0.243387  0.955517  1
# 96  0.425830  0.558842  0.882604  0.006876  1
# 97  0.648032  0.740276  0.952679  0.380081  1
# 98  0.351730  0.749145  0.494610  0.132309  1
# 99  0.435426  0.093732  0.981898  0.927521  1
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Ans of question 3

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split


data = pd.read_csv(r'caesarian.csv', header=None, skiprows=17)

framedData = pd.DataFrame(data)

X_train, X_test, Y_train, Y_test = train_test_split(framedData.drop(5, axis = 1), framedData[5], test_size = 0.2, random_state = 22)

framedData
# Out:
#      0  1  2  3  4  5
# 0   22  1  0  2  0  0
# 1   26  2  0  1  0  1
# 2   26  2  1  1  0  0
# 3   28  1  0  2  0  0
# 4   22  2  0  1  0  1
# ..  .. .. .. .. .. ..
# 75  27  2  1  1  0  0
# 76  33  4  0  1  0  1
# 77  29  2  1  2  0  1
# 78  25  1  2  0  0  1
# 79  24  2  2  1  0  0
#
# [80 rows x 6 columns]
